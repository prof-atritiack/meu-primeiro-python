# %% [markdown]
# # Bootcamp: Meu Primeiro Código em Python
#
# Bem-vinda ao seu primeiro contato com programação!
# Hoje vamos aprender juntos o básico da linguagem **Python** usando o Google Colab.
#
# > Sempre que você encontrar uma célula com `# SEU CÓDIGO AQUI`, tente escrever sua resposta ali 😊

# %% [markdown]
# ## 1. Primeiros comandos com `print()`

# %%
# Escreva uma mensagem para você mesma aqui
# SEU CÓDIGO AQUI

# %% [markdown]
# ## 2. Criando variáveis

# %%
# Crie variáveis com seu nome, idade e altura
# SEU CÓDIGO AQUI

# %% [markdown]
# ## 3. Usando `input()` para conversar com o usuário

# %%
# Peça para a pessoa digitar o nome e diga olá para ela
# SEU CÓDIGO AQUI

# %% [markdown]
# ## 4. Condições com `if`, `else` e `elif`

# %%
# Descubra se a pessoa é maior de idade ou não
# SEU CÓDIGO AQUI

# %% [markdown]
# ## 5. Repetições com `for`

# %%
# Mostre os números de 1 a 10 na tela
# SEU CÓDIGO AQUI

# %% [markdown]
# ## 6. Repetições com `while`

# %%
# Conte até 5 usando while
# SEU CÓDIGO AQUI

# %% [markdown]
# ## 7. Trabalhando com listas

# %%
# Crie uma lista com 3 frutas e mostre cada uma delas
# SEU CÓDIGO AQUI

# %% [markdown]
# ## 8. Criando sua primeira função

# %%
# Crie uma função chamada 'saudacao' que receba um nome e imprima uma mensagem
# SEU CÓDIGO AQUI

# %% [markdown]
# ## Mini Projeto: Jogo da Adivinhação 🎯

# %% [markdown]
# Crie um jogo onde:
# 1. O computador escolhe um número entre 1 e 10.
# 2. A pessoa tenta adivinhar.
# 3. O programa diz se ela acertou ou não.
#
# Você pode usar:
# - `import random`
# - `random.randint(1, 10)`
# - `input()` e `int()`
# - `if` e `else`

# %%
# SEU CÓDIGO AQUI
