# %% [markdown]
# # Bootcamp: Meu Primeiro Código em Python

# %%
print("Olá, mundo!")

# %%
nome = "Ana"
idade = 14
altura = 1.55
print("Nome:", nome)
print("Idade:", idade)
print("Altura:", altura)

# %%
nome = input("Qual o seu nome? ")
print("Muito prazer, " + nome + "!")

# %%
idade = int(input("Quantos anos você tem? "))
if idade >= 18:
    print("Você é maior de idade!")
else:
    print("Você ainda é menor de idade.")

# %%
for i in range(1, 6):
    print("Número:", i)

# %%
numero = 0
while numero < 5:
    print("Número atual:", numero)
    numero += 1

# %%
frutas = ["maçã", "banana", "uva"]
for fruta in frutas:
    print("Eu gosto de", fruta)

# %%
def saudacao(nome):
    print("Olá,", nome, "! Bem-vinda ao Python!")
saudacao("Ana")

# %% [markdown]
# ## Mini Projeto: Jogo da Adivinhação

# %%
import random
numero_secreto = random.randint(1, 10)
tentativa = int(input("Tente adivinhar o número (1 a 10): "))
if tentativa == numero_secreto:
    print("Parabéns! Você acertou!")
else:
    print("Que pena! O número era", numero_secreto)
